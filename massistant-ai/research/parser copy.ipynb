# %%
from gigachat_api import GigaChat

gigachat = GigaChat()

# %%
import pandas as pd

filename = 'data1.xlsx'
df = gigachat.process(filename)
df
# Out:
# 2\11
# /home/prof_evaluation/miniconda3/envs/mass/lib/python3.9/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ngw.devices.sberbank.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/prof_evaluation/miniconda3/envs/mass/lib/python3.9/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gigachat.devices.sberbank.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#                                                 chunk  \
# 0    Привет ! Меня зовут Владислав Ефимов , я рабо...
# 1    А скомбинировав это с разработкой веб-приложе...
# 2    Давайте выведем стандартный для начала курсов...
# 3    Мы сейчас рассмотрели варианты разработки в и...
# 4    Если мы хотим его сохранить , то можно это вы...
# 5    Первая строка , она на самом деле аналогична ...
# 6    Что значит этот код ? Значит , что в переменн...
# 7    Для чего это нужно ? Это , во-первых , называ...
# 8    Потому что мы с этими данными ничего не делал...
# 9    И на самом деле запускается Python интерпрета...
# 10   На этом уроке мы познакомились с интерпретато...
#
#                                              keywords
# 0   1. Python\n2. IT-профессии\n3. Интепретируемый...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN

# %%
import re
import itertools
data = []

for index, row in df.iterrows():
    keywords = re.split(r'\n\d+\.', row.keywords[3:].lower())
    new_keywords = []
    for key in keywords:
        tmp = re.split(r'\s+', re.sub(r'^\s+|\s+$', '', key))
        if len(tmp) > 1:
            perms = list(itertools.permutations(tmp))
            perms = [' '.join(items) for items in perms]
            new_keywords.extend(perms)
        else:
            new_keywords.append(tmp[0])

    data.append([re.split(r'\s+', row.chunk.lower()), new_keywords])
    break

data[0]
# Out:
# [['',
#   'привет',
#   '!',
#   'меня',
#   'зовут',
#   'владислав',
#   'ефимов',
#   ',',
#   'я',
#   'работаю',
#   'в',
#   'команде',
#   'вк',
#   'рекламы',
#   '.',
#   'прежде',
#   'чем',
#   'приступить',
#   'к',
#   'изучению',
#   'языка',
#   ',',
#   'я',
#   'кратко',
#   'расскажу',
#   'о',
#   'преимуществах',
#   'этого',
#   'языка',
#   'программирования',
#   ',',
#   'какие',
#   'задачи',
#   'можно',
#   'с',
#   'помощью',
#   'него',
#   'решать',
#   'и',
#   'в',
#   'каких',
#   'it',
#   '-',
#   'профессиях',
#   'он',
#   'используется',
#   '.',
#   'начнем',
#   'с',
#   'отличительных',
#   'преимуществ',
#   'языка',
#   '.',
#   'во-первых',
#   ',',
#   'это',
#   'простой',
#   'для',
#   'понимания',
#   'использование',
#   'язык',
#   '.',
#   'у',
#   'языка',
#   'python',
#   ',',
#   'пожалуй',
#   ',',
#   'один',
#   'из',
#   'самых',
#   'простых',
#   'и',
#   'понятных',
#   'синтаксисов',
#   'относительно',
#   'других',
#   'языков',
#   '.',
#   'во-вторых',
#   ',',
#   'язык',
#   'интерпретируемый',
#   '.',
#   'это',
#   'значит',
#   ',',
#   'что',
#   'вы',
#   'можете',
#   'написать',
#   'код',
#   'и',
#   'сразу',
#   'его',
#   'запустить',
#   ',',
#   'не',
#   'прибегая',
#   'к',
#   'шагу',
#   'компиляции',
#   '.',
#   'он',
#   'позволяет',
#   'исполнять',
#   'код',
#   'строка',
#   'за',
#   'строкой',
#   ',',
#   'что',
#   'бывает',
#   'очень',
#   'удобно',
#   'и',
#   'полезно',
#   'при',
#   'разработке',
#   'и',
#   'исследованиях',
#   '.',
#   'в-третьих',
#   ',',
#   'это',
#   'популярный',
#   'язык',
#   ',',
#   'а',
#   'значит',
#   'для',
#   'него',
#   'существует',
#   'множество',
#   'готовых',
#   'библиотек',
#   ',',
#   'которые',
#   'решают',
#   'реальные',
#   'задачи',
#   ',',
#   'а',
#   'не',
#   'придется',
#   'придумывать',
#   'и',
#   'писать',
#   'какие-то',
#   'вещи',
#   'с',
#   'нуля',
#   '.',
#   'в-четвертых',
#   ',',
#   'популярность',
#   'языка',
#   'также',
#   'означает',
#   'большое',
#   'сообщество',
#   'разработчиков',
#   'и',
#   'энтузиастов',
#   '.',
#   'из-за',
#   'этого',
#   'в',
#   'сети',
#   'можно',
#   'найти',
#   'много',
#   'гайдов',
#   ',',
#   'обсуждений',
#   ',',
#   'обучающих',
#   'материалов',
#   'и',
#   'многого',
#   'другого',
#   '.',
#   'и',
#   'в-пятых',
#   ',',
#   'портативность',
#   '.',
#   'код',
#   'на',
#   'python',
#   ',',
#   'написанный',
#   'на',
#   'одной',
#   'платформе',
#   ',',
#   'например',
#   ',',
#   'на',
#   'mac',
#   ',',
#   'спокойно',
#   'запустится',
#   'на',
#   'другой',
#   ',',
#   'например',
#   ',',
#   'на',
#   'windows',
#   '.',
#   'если',
#   'говорить',
#   'об',
#   'областях',
#   'применения',
#   ',',
#   'то',
#   'язык',
#   'python',
#   'применяется',
#   'во',
#   'многих',
#   ',',
#   'например',
#   ',',
#   'в',
#   'областях',
#   ',',
#   'например',
#   ',',
#   'во-первых',
#   ',',
#   'это',
#   'веб-разработка',
#   '.',
#   'можно',
#   'строить',
#   'бэкэнд',
#   '-',
#   'веб-приложения',
#   'в',
#   'качестве',
#   'веб-разработчика',
#   '.',
#   'большой',
#   'набор',
#   'библиотек',
#   'и',
#   'встроенных',
#   'инструментов',
#   'позволяет',
#   'построить',
#   'как',
#   'небольшое',
#   'приложение',
#   ',',
#   'так',
#   'и',
#   'большой',
#   'сложный',
#   'сервис',
#   'с',
#   'базами',
#   'данных',
#   'и',
#   'микросервисами',
#   '.',
#   'во-вторых',
#   ',',
#   'машинное',
#   'обучение',
#   'и',
#   'искусственный',
#   'интеллект',
#   '.',
#   'в',
#   'качестве',
#   'ml-специалиста',
#   'можно',
#   'разрабатывать',
#   'различные',
#   'решения',
#   'на',
#   'этом',
#   'языке',
#   '.',
#   'от',
#   'простых',
#   'статистических',
#   'моделей',
#   'до',
#   'сложных',
#   'нейронных',
#   'сетей',
#   '.'],
#  ['python',
#   'it-профессии',
#   'интепретируемый язык',
#   'язык интепретируемый',
#   'библиотеки',
#   'портативность',
#   'веб-разработка',
#   'бэкэнд-разработка',
#   'машинное обучение',
#   'обучение машинное',
#   'искусственный интеллект',
#   'интеллект искусственный',
#   'ml-специалист']]

# %%
pd.DataFrame(data=data, columns=['chunk', 'keywords']).to_excel('data_with_keywords.xlsx', index=False)

# %%
from sentence_splitter import SyntaxAnalyzer

a = SyntaxAnalyzer()

# %%
import ast
df = pd.read_excel('data_with_keywords.xlsx')

data = []
for index, row in df.iterrows():
    chunk = ast.literal_eval(row.chunk)[280:]

    bio_markup = []
    for i in range(len(chunk)):
        was_added = False
        for key in ast.literal_eval(row.keywords):
            # print(key)
            print(bio_markup)
            print(key, '|', chunk[i])
            parts = re.split(r'\s+', key)
            chunk[i]

            if len(parts) == 1:
                if chunk[i] == key:
                    bio_markup.append('B')
                    was_added=True
                    break
                else:
                    continue
                    # bio_markup.append('O')
            else:
                # print(len(chunk), i, len(parts))
                if len(chunk) - i > len(parts):
                    cur = []
                    if chunk[i] == parts[0]:
                        cur.append('B')
                    else:
                        continue
                    for j in (1, len(parts)):
                        # print(parts)
                        # print(j)
                        # print(parts[j])
                        if chunk[i+j] == parts[j]:
                            cur.append('I')
                        else:
                            break
                    if len(cur) == len(parts):
                        i += len(parts)
                        was_added=True
                        bio_markup.extend(cur)
                        break
                else:
                    continue
                    # bio_markup.append('O')
        if not was_added:
            bio_markup.append('O')

    break
# Out:
# []
# python | разрабатывать
# []
# it-профессии | разрабатывать
# []
# интепретируемый язык | разрабатывать
# []
# язык интепретируемый | разрабатывать
# []
# библиотеки | разрабатывать
# []
# портативность | разрабатывать
# []
# веб-разработка | разрабатывать
# []
# бэкэнд-разработка | разрабатывать
# []
# машинное обучение | разрабатывать
# []
# обучение машинное | разрабатывать
# []
# искусственный интеллект | разрабатывать
# []
# интеллект искусственный | разрабатывать
# []
# ml-специалист | разрабатывать
# ['O']
# python | различные
# ['O']
# it-профессии | различные
# ['O']
# интепретируемый язык | различные
# ['O']
# язык интепретируемый | различные
# ['O']
# библиотеки | различные
# ['O']
# портативность | различные
# ['O']
# веб-разработка | различные
# ['O']
# бэкэнд-разработка | различные
# ['O']
# машинное обучение | различные
# ['O']
# обучение машинное | различные
# ['O']
# искусственный интеллект | различные
# ['O']
# интеллект искусственный | различные
# ['O']
# ml-специалист | различные
# ['O', 'O']
# python | решения
# ['O', 'O']
# it-профессии | решения
# ['O', 'O']
# интепретируемый язык | решения
# ['O', 'O']
# язык интепретируемый | решения
# ['O', 'O']
# библиотеки | решения
# ['O', 'O']
# портативность | решения
# ['O', 'O']
# веб-разработка | решения
# ['O', 'O']
# бэкэнд-разработка | решения
# ['O', 'O']
# машинное обучение | решения
# ['O', 'O']
# обучение машинное | решения
# ['O', 'O']
# искусственный интеллект | решения
# ['O', 'O']
# интеллект искусственный | решения
# ['O', 'O']
# ml-специалист | решения
# ['O', 'O', 'O']
# python | на
# ['O', 'O', 'O']
# it-профессии | на
# ['O', 'O', 'O']
# интепретируемый язык | на
# ['O', 'O', 'O']
# язык интепретируемый | на
# ['O', 'O', 'O']
# библиотеки | на
# ['O', 'O', 'O']
# портативность | на
# ['O', 'O', 'O']
# веб-разработка | на
# ['O', 'O', 'O']
# бэкэнд-разработка | на
# ['O', 'O', 'O']
# машинное обучение | на
# ['O', 'O', 'O']
# обучение машинное | на
# ['O', 'O', 'O']
# искусственный интеллект | на
# ['O', 'O', 'O']
# интеллект искусственный | на
# ['O', 'O', 'O']
# ml-специалист | на
# ['O', 'O', 'O', 'O']
# python | этом
# ['O', 'O', 'O', 'O']
# it-профессии | этом
# ['O', 'O', 'O', 'O']
# интепретируемый язык | этом
# ['O', 'O', 'O', 'O']
# язык интепретируемый | этом
# ['O', 'O', 'O', 'O']
# библиотеки | этом
# ['O', 'O', 'O', 'O']
# портативность | этом
# ['O', 'O', 'O', 'O']
# веб-разработка | этом
# ['O', 'O', 'O', 'O']
# бэкэнд-разработка | этом
# ['O', 'O', 'O', 'O']
# машинное обучение | этом
# ['O', 'O', 'O', 'O']
# обучение машинное | этом
# ['O', 'O', 'O', 'O']
# искусственный интеллект | этом
# ['O', 'O', 'O', 'O']
# интеллект искусственный | этом
# ['O', 'O', 'O', 'O']
# ml-специалист | этом
# ['O', 'O', 'O', 'O', 'O']
# python | языке
# ['O', 'O', 'O', 'O', 'O']
# it-профессии | языке
# ['O', 'O', 'O', 'O', 'O']
# интепретируемый язык | языке
# ['O', 'O', 'O', 'O', 'O']
# язык интепретируемый | языке
# ['O', 'O', 'O', 'O', 'O']
# библиотеки | языке
# ['O', 'O', 'O', 'O', 'O']
# портативность | языке
# ['O', 'O', 'O', 'O', 'O']
# веб-разработка | языке
# ['O', 'O', 'O', 'O', 'O']
# бэкэнд-разработка | языке
# ['O', 'O', 'O', 'O', 'O']
# машинное обучение | языке
# ['O', 'O', 'O', 'O', 'O']
# обучение машинное | языке
# ['O', 'O', 'O', 'O', 'O']
# искусственный интеллект | языке
# ['O', 'O', 'O', 'O', 'O']
# интеллект искусственный | языке
# ['O', 'O', 'O', 'O', 'O']
# ml-специалист | языке
# ['O', 'O', 'O', 'O', 'O', 'O']
# python | .
# ['O', 'O', 'O', 'O', 'O', 'O']
# it-профессии | .
# ['O', 'O', 'O', 'O', 'O', 'O']
# интепретируемый язык | .
# ['O', 'O', 'O', 'O', 'O', 'O']
# язык интепретируемый | .
# ['O', 'O', 'O', 'O', 'O', 'O']
# библиотеки | .
# ['O', 'O', 'O', 'O', 'O', 'O']
# портативность | .
# ['O', 'O', 'O', 'O', 'O', 'O']
# веб-разработка | .
# ['O', 'O', 'O', 'O', 'O', 'O']
# бэкэнд-разработка | .
# ['O', 'O', 'O', 'O', 'O', 'O']
# машинное обучение | .
# ['O', 'O', 'O', 'O', 'O', 'O']
# обучение машинное | .
# ['O', 'O', 'O', 'O', 'O', 'O']
# искусственный интеллект | .
# ['O', 'O', 'O', 'O', 'O', 'O']
# интеллект искусственный | .
# ['O', 'O', 'O', 'O', 'O', 'O']
# ml-специалист | .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# python | от
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# it-профессии | от
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# интепретируемый язык | от
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# язык интепретируемый | от
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# библиотеки | от
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# портативность | от
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# веб-разработка | от
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# бэкэнд-разработка | от
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# машинное обучение | от
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# обучение машинное | от
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# искусственный интеллект | от
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# интеллект искусственный | от
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ml-специалист | от
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# python | простых
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# it-профессии | простых
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интепретируемый язык | простых
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# язык интепретируемый | простых
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# библиотеки | простых
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# портативность | простых
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# веб-разработка | простых
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# бэкэнд-разработка | простых
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# машинное обучение | простых
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# обучение машинное | простых
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# искусственный интеллект | простых
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интеллект искусственный | простых
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ml-специалист | простых
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# python | статистических
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# it-профессии | статистических
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интепретируемый язык | статистических
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# язык интепретируемый | статистических
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# библиотеки | статистических
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# портативность | статистических
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# веб-разработка | статистических
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# бэкэнд-разработка | статистических
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# машинное обучение | статистических
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# обучение машинное | статистических
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# искусственный интеллект | статистических
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интеллект искусственный | статистических
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ml-специалист | статистических
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# python | моделей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# it-профессии | моделей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интепретируемый язык | моделей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# язык интепретируемый | моделей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# библиотеки | моделей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# портативность | моделей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# веб-разработка | моделей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# бэкэнд-разработка | моделей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# машинное обучение | моделей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# обучение машинное | моделей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# искусственный интеллект | моделей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интеллект искусственный | моделей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ml-специалист | моделей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# python | до
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# it-профессии | до
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интепретируемый язык | до
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# язык интепретируемый | до
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# библиотеки | до
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# портативность | до
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# веб-разработка | до
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# бэкэнд-разработка | до
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# машинное обучение | до
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# обучение машинное | до
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# искусственный интеллект | до
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интеллект искусственный | до
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ml-специалист | до
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# python | сложных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# it-профессии | сложных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интепретируемый язык | сложных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# язык интепретируемый | сложных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# библиотеки | сложных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# портативность | сложных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# веб-разработка | сложных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# бэкэнд-разработка | сложных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# машинное обучение | сложных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# обучение машинное | сложных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# искусственный интеллект | сложных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интеллект искусственный | сложных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ml-специалист | сложных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# python | нейронных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# it-профессии | нейронных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интепретируемый язык | нейронных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# язык интепретируемый | нейронных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# библиотеки | нейронных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# портативность | нейронных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# веб-разработка | нейронных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# бэкэнд-разработка | нейронных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# машинное обучение | нейронных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# обучение машинное | нейронных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# искусственный интеллект | нейронных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интеллект искусственный | нейронных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ml-специалист | нейронных
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# python | сетей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# it-профессии | сетей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интепретируемый язык | сетей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# язык интепретируемый | сетей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# библиотеки | сетей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# портативность | сетей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# веб-разработка | сетей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# бэкэнд-разработка | сетей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# машинное обучение | сетей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# обучение машинное | сетей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# искусственный интеллект | сетей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интеллект искусственный | сетей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ml-специалист | сетей
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# python | .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# it-профессии | .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интепретируемый язык | .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# язык интепретируемый | .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# библиотеки | .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# портативность | .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# веб-разработка | .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# бэкэнд-разработка | .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# машинное обучение | .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# обучение машинное | .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# искусственный интеллект | .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# интеллект искусственный | .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ml-специалист | .

# %%
dict(zip(chunk, bio_markup))
# Out:
# {'': 'O',
#  'привет': 'O',
#  '!': 'O',
#  'меня': 'O',
#  'зовут': 'O',
#  'владислав': 'O',
#  'ефимов': 'O',
#  ',': 'O',
#  'я': 'O',
#  'работаю': 'O',
#  'в': 'O',
#  'команде': 'O',
#  'вк': 'O',
#  'рекламы': 'O',
#  '.': 'O',
#  'прежде': 'O',
#  'чем': 'O',
#  'приступить': 'O',
#  'к': 'O',
#  'изучению': 'O',
#  'языка': 'O',
#  'кратко': 'O',
#  'расскажу': 'O',
#  'о': 'O',
#  'преимуществах': 'O',
#  'этого': 'O',
#  'программирования': 'O',
#  'какие': 'O',
#  'задачи': 'O',
#  'можно': 'O',
#  'с': 'O',
#  'помощью': 'O',
#  'него': 'O',
#  'решать': 'O',
#  'и': 'O',
#  'каких': 'O',
#  'it': 'O',
#  '-': 'O',
#  'профессиях': 'O',
#  'он': 'O',
#  'используется': 'O',
#  'начнем': 'O',
#  'отличительных': 'O',
#  'преимуществ': 'O',
#  'во-первых': 'O',
#  'это': 'O',
#  'простой': 'O',
#  'для': 'O',
#  'понимания': 'O',
#  'использование': 'O',
#  'язык': 'O',
#  'у': 'O',
#  'python': 'B',
#  'пожалуй': 'O',
#  'один': 'O',
#  'из': 'O',
#  'самых': 'O',
#  'простых': 'O',
#  'понятных': 'O',
#  'синтаксисов': 'O',
#  'относительно': 'O',
#  'других': 'O',
#  'языков': 'O',
#  'во-вторых': 'O',
#  'интерпретируемый': 'O',
#  'значит': 'O',
#  'что': 'O',
#  'вы': 'O',
#  'можете': 'O',
#  'написать': 'O',
#  'код': 'O',
#  'сразу': 'O',
#  'его': 'O',
#  'запустить': 'O',
#  'не': 'O',
#  'прибегая': 'O',
#  'шагу': 'O',
#  'компиляции': 'O',
#  'позволяет': 'O',
#  'исполнять': 'O',
#  'строка': 'O',
#  'за': 'O',
#  'строкой': 'O',
#  'бывает': 'O',
#  'очень': 'O',
#  'удобно': 'O',
#  'полезно': 'O',
#  'при': 'O',
#  'разработке': 'O',
#  'исследованиях': 'O',
#  'в-третьих': 'O',
#  'популярный': 'O',
#  'а': 'O',
#  'существует': 'O',
#  'множество': 'O',
#  'готовых': 'O',
#  'библиотек': 'O',
#  'которые': 'O',
#  'решают': 'O',
#  'реальные': 'O',
#  'придется': 'O',
#  'придумывать': 'O',
#  'писать': 'O',
#  'какие-то': 'O',
#  'вещи': 'O',
#  'нуля': 'O',
#  'в-четвертых': 'O',
#  'популярность': 'O',
#  'также': 'O',
#  'означает': 'O',
#  'большое': 'O',
#  'сообщество': 'O',
#  'разработчиков': 'O',
#  'энтузиастов': 'O',
#  'из-за': 'O',
#  'сети': 'O',
#  'найти': 'O',
#  'много': 'O',
#  'гайдов': 'O',
#  'обсуждений': 'O',
#  'обучающих': 'O',
#  'материалов': 'O',
#  'многого': 'O',
#  'другого': 'O',
#  'в-пятых': 'O',
#  'портативность': 'B',
#  'на': 'O',
#  'написанный': 'O',
#  'одной': 'O',
#  'платформе': 'O',
#  'например': 'O',
#  'mac': 'O',
#  'спокойно': 'O',
#  'запустится': 'O',
#  'другой': 'O',
#  'windows': 'O',
#  'если': 'O',
#  'говорить': 'O',
#  'об': 'O',
#  'областях': 'O',
#  'применения': 'O',
#  'то': 'O',
#  'применяется': 'O',
#  'во': 'O',
#  'многих': 'O',
#  'веб-разработка': 'B',
#  'строить': 'O',
#  'бэкэнд': 'O',
#  'веб-приложения': 'O',
#  'качестве': 'O',
#  'веб-разработчика': 'O',
#  'большой': 'O',
#  'набор': 'O',
#  'встроенных': 'O',
#  'инструментов': 'O',
#  'построить': 'O',
#  'как': 'O',
#  'небольшое': 'O',
#  'приложение': 'O',
#  'так': 'O',
#  'сложный': 'O',
#  'сервис': 'O',
#  'базами': 'O',
#  'данных': 'O',
#  'микросервисами': 'O',
#  'машинное': 'O',
#  'обучение': 'O',
#  'искусственный': 'O',
#  'интеллект': 'O',
#  'ml-специалиста': 'O',
#  'разрабатывать': 'O',
#  'различные': 'O',
#  'решения': 'O',
#  'этом': 'O',
#  'языке': 'O',
#  'от': 'O',
#  'статистических': 'O',
#  'моделей': 'O',
#  'до': 'O',
#  'сложных': 'O',
#  'нейронных': 'O',
#  'сетей': 'O'}

# %%
re.split(' ', 'privet')
# Out:
# ['privet']
